# %% [markdown]
# # STA 141B Assignment 4
#
# Due __Feb 22, 2019__ by 11:59pm. Submit by editing this file, committing the changes with git, and then pushing to your private GitHub repo for the assignment. This assignment will be graded according to the class rubric.
#
# Please do not rename this file or delete the exercise cells, because it will interfere with our grading tools. Put your answers in new cells after each exercise. You can make as many new cells as you like. Use code cells for code and Markdown cells for text. Answer all questions with complete sentences.
#
# The purpose of this assignment is to practice scraping data from web pages.

# %%
# Our usual data science tools
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sp
import lxml.html as lx
import requests
import requests_cache
requests_cache.install_cache("../sfchronicle")
import time
import re
import nltk
import nltk.corpus
nltk.download('stopwords')
from itertools import chain
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


# References: 

# https://stackoverflow.com/questions/11860476/how-to-unnest-a-nested-list: Used it to unlist my nested list in 1.4
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/rohanmalhotra/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## The San Francisco Chronicle
#
# In this assignment, you'll scrape text from [The San Francisco Chronicle](https://www.sfchronicle.com/) newspaper and then analyze the text.
#
# The Chronicle is organized by category into article lists. For example, there's a [Local](https://www.sfchronicle.com/local/) list, [Sports](https://www.sfchronicle.com/sports/) list, and [Food](https://www.sfchronicle.com/food/) list.
#
# The goal of exercises 1.1 - 1.3 is to scrape articles from the Chronicle for analysis in exercise 1.4.

# %% [markdown]
# __Exercise 1.1.__ Write a function that extracts all of the links to articles in a Chronicle article list. The function should:
#
# * Have a parameter `url` for the URL of the article list.
#
# * Return a list of article URLs (each URL should be a string).
#
# Test your function on 2-3 different categories to make sure it works.
#
# Hints:
#
# * Be polite and save time by setting up [requests_cache](https://pypi.python.org/pypi/requests-cache) before you write your function.
#
# * You can use any of the XML/HTML parsing packages mentioned in class. Choose one and use it throughout the entire assignment.

# %%
def get_articles(url):
    
    ''' Function takes in a page from the sf chronicle and returns, 
    every article on that page'''
    
    try:
        
        # Get the website
        response = requests.get(url)
        time.sleep(2)
        response.raise_for_status()
    
        # Format it like an html 
        html = lx.fromstring(response.text)
        html.make_links_absolute(url)
    
        # Get the articles on the page 
        main_articles = html.xpath("//h2[contains(@class, 'headline')]/a/@href") # Gets the main articles for each section
        related_articles = html.xpath("//div[contains(@class,'item rel-links')]/h4/a/@href") # Gets other articles related to the main one 
        final = set(main_articles + related_articles)
        final = list(final)
    
        # Since articles have a .php at the end of the link i will only extract those to make sure i get articles only
        articles = [item for item in final if "php" in item]
    
    except:
        print("The url was either invalid or the incorrect format")
        return None
    
    return articles

# %%
# Buisness articles: 
biz = get_articles("https://www.sfchronicle.com/business/")
biz[:5]
# Out:
# ['https://www.sfchronicle.com/business/article/Amazon-dumps-NYC-headquarters-and-its-promised-13617774.php',
#  'https://www.sfchronicle.com/news/world/article/Asian-stocks-rally-on-hope-of-further-China-US-13624395.php',
#  'https://www.sfchronicle.com/realestate/article/Designer-Profile-Lowell-Strauss-of-Amalfi-West-13620501.php',
#  'https://www.sfchronicle.com/business/article/Long-winding-road-led-to-get-touch-registration-12617780.php',
#  'https://www.sfchronicle.com/bayarea/article/CleanPowerSF-tripling-households-served-with-13618155.php']

# %%
# Sports articles: 
sports = get_articles("https://www.sfchronicle.com/sports/")
sports[:5]
# Out:
# ['https://www.sfchronicle.com/49ers/article/49ers-GM-John-Lynch-will-be-the-one-to-watch-13484514.php',
#  'https://www.sfchronicle.com/sports/golf/article/Hailstorm-slams-Pebble-Beach-during-final-round-13605371.php',
#  'https://www.sfchronicle.com/collegesports/article/USF-uses-late-rally-to-overcome-Pepperdine-29-13618708.php',
#  'https://www.sfchronicle.com/49ers/article/Will-49ers-put-franchise-tag-on-kicker-Robbie-13626054.php',
#  'https://www.sfchronicle.com/athletics/article/A-s-great-Rickey-Henderson-was-gung-ho-to-13622452.php']

# %%
# lifestyle  articles:
lifestyle = get_articles("https://www.sfchronicle.com/lifestyle/")
lifestyle[:5]
# Out:
# ['https://www.sfchronicle.com/homeandgarden/article/Modern-Carmel-Valley-home-welcomes-land-and-sky-12232711.php',
#  'https://www.sfchronicle.com/style/article/Asian-Art-Museum-shows-the-kimono-s-13594758.php',
#  'https://www.sfchronicle.com/travel/article/Podcast-Ultrarunner-Dean-Karnazes-on-recovery-13595254.php',
#  'https://www.sfchronicle.com/style/article/Galas-galore-CMPC-celebrates-new-hospital-13608478.php',
#  'https://www.sfchronicle.com/travel/article/Lake-Tahoe-houses-sit-vacant-while-locals-13601651.php']

# %% [markdown]
# __Exercise 1.2.__ Write a function that extracts data from a Chronicle article. The function should:
#
# * Have a parameter `url` for the URL of the article.
#
# * Return a dictionary with keys for:
#     + `url`: The URL of the article.
#     + `title`: The title of the article.
#     + `text`: The complete text of the article.
#     + `author`: The author's name (if available) or a suitable missing value.
#     + `date`: The date and time the article was published.
#     + `date_updated`: The date and time the article was last updated (if available) or a suitable missing value.
#
# For example, for [this article](https://www.sfchronicle.com/homeandgarden/article/Gardenlust-looks-at-best-21st-century-13580871.php) your function should return a dictionary with the form:
# ```js
# {'url': 'https://www.sfchronicle.com/homeandgarden/article/Gardenlust-looks-at-best-21st-century-13580871.php',
#  'title': '‘Gardenlust’ looks at best 21st century gardens in the world',
#  'text': 'The book...',
#  'author': 'Pam Peirce',
#  'date': '2019-02-01T18:02:33+00:00',
#  'date_updated': '2019-02-01T18:12:53+00:00'}
# ```
# The value of the `text` field is omitted here to save space. Your function should return the full text in the `text` field.
#
# Hints:
#
# * Many parsing packages allow you to delete elements from an HTML document. Deleting elements is one way to avoid extracting unwanted tags.
# * You can union multiple XPath paths with `|`.

# %%
def get_article_info(article):
   
    ''' Function takes in a link of an article from the sf chronicle and extracts features
        such as author,title,date published and updated from that article'''
    
    response = requests.get(article)
    html = lx.fromstring(response.text)
    
    # Getting the title
    try:
        title = html.xpath("//h1[contains(@class, 'header-title')]|//h1[contains(@class,'headline entry-title')]")[0]
        title = title.text
    
    except:
        title = None

    # Getting the text of the article 
    try:
        contents = html.xpath("//section[contains(@class, 'body')]//p|//div[contains(@class, 'article-body')]//p")
        all_text = [content.text_content() for content in contents]
        all_text = "".join(all_text)
        
    except:
        all_text = None

    # Author 
    try:
        author = html.xpath("//span[@class ='header-authors-name']|//p[contains(@class,'byline')]//a")
        if len(author) == 2:
            author1 = author[0].text_content()
            author2 = author[1].text_content()
            if author1 == author2:
                author = author[0].text_content()
            else:
                author = author1 + " and " + author2
        else:
            author = author[0].text_content()
    except:
        author = None
        try:
            author = html.xpath("//div//span[@class = 'header-byline']")[0]
            author = author.text_content().strip()
            author = re.sub(r'^By ','', author)
            if author == '':
                author = None     
        except:
            author = None

    # Dates
    get_date = html.xpath("//time/@datetime")

    # Published Date 
    try:
        pub_date = get_date[0]
    
    except:
        pub_date = None

    # Updated date
    try:
        updated = get_date[1]
    
    except:
        updated = None
    
    return {"url": article, "title": title, "text": all_text, "author": author, "date": pub_date, "date_updated": updated}

# Tests:
# get_article_info("https://www.sfchronicle.com/homeandgarden/article/Gardenlust-looks-at-best-21st-century-13580871.php")
# get_article_info("https://www.sfchronicle.com/politics/article/Trump-administration-cancels-funding-for-CA-13628908.php")
# get_article_info("https://www.sfchronicle.com/food/article/Remodel-creates-an-airy-house-of-mirth-for-family-11297009.php")

# %% [markdown]
# __Exercise 1.3.__ Use your functions from exercises 1.1 and 1.2 to get data frames of articles for the "Biz+Tech" category as well as two other categories of your choosing (except for "Vault: Archive", "Podcasts", and "In Depth").
#
# Add a column to each that indicates the category, then combine them into one big data frame. Clean up the data, stripping excess whitespace and converting columns to appropriate dtypes.
#
# The `text` column of this data frame will be your corpus for natural language processing in exercise 1.4.

# %%
# Using article categories I tested my get_articles function on in 1.1 
# biz
biz_info = [get_article_info(art) for art in biz]
biz_df = pd.DataFrame(biz_info)
biz_df["category"] = "Biz + tech"

# %%
# Sports
sports_info = [get_article_info(art) for art in sports]
sports_df = pd.DataFrame(sports_info)
sports_df["category"] = "sports"

# %%
# lifestyle
lifestyle_info = [get_article_info(art) for art in lifestyle]
lifestyle_df = pd.DataFrame(lifestyle_info)
lifestyle_df["category"] = "lifestyle"

# %%
# Combining the data frames
full_df = pd.concat([lifestyle_df,sports_df,biz_df])
full_df = full_df.reset_index(drop = True)
full_df["url"][0]
# Out:
# 'https://www.sfchronicle.com/homeandgarden/article/Modern-Carmel-Valley-home-welcomes-land-and-sky-12232711.php'

# %%
# Cleaning the data frame
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 7 columns):
# author          139 non-null object
# date            135 non-null object
# date_updated    111 non-null object
# text            141 non-null object
# title           141 non-null object
# url             141 non-null object
# category        141 non-null object
# dtypes: object(7)
# memory usage: 7.8+ KB

# %% [markdown]
# Every column should be a string,but date and date_updated as they should be date time objects so those are the only  two types that I will change as the rest are what I want them to be

# %%
# Converting the data types
full_df["date"] = pd.to_datetime(full_df["date"])
full_df["date_updated"] = pd.to_datetime(full_df["date_updated"])

# %%
# Checking the titles to see if theres more patterns
no_title = full_df[full_df["title"].isna()]

# %% [markdown]
# Added pattern for titles under the class of headline entry-title, and now every post has a title

# %%
# Checking the author's to see if theres more patterns 
no_author =  full_df[full_df["author"].isna()]

# %% [markdown]
# There was a pattern in which the authors in some link would be "by ... " so incorporated that pattern into my function
# and i clean it within the function so i get rid of the "by" and get just the author name, but there seems to be 2 posts with no authors still after checking the links i did not see any author

# %% [markdown]
# ###### Overall, I feel my data frame came out formatted right mainly due to the way i scraped the data,only changes needed were converting the date and date_updated to date time objects and  I got more patterns to get almost all the data for each article

# %%
full_df
# Out:
#                                     author                date  \
# 0                        Laura Mauk-Caines 2017-09-27 16:44:41
# 1                               Tony Bravo 2019-02-08 17:41:55
# 2                           Gregory Thomas 2019-02-06 21:16:50
# 3                        Catherine Bigelow 2019-02-18 18:25:10
# 4                                Dave Zook 2019-02-08 18:43:29
# 5                            Tom Stienstra 2019-02-08 19:42:27
# 6                         Brenda Wong Aoki 2019-02-14 20:00:53
# 7                            Tom Stienstra 2019-02-15 19:28:51
# 8                               Julie Chai 2015-07-10 07:01:00
# 9                        Catherine Bigelow 2019-02-20 17:39:32
# 10                           Gail Goldberg 2019-02-07 22:29:26
# 11                              Tony Bravo 2019-02-13 00:25:10
# 12                           Tom Stienstra 2019-02-18 08:00:00
# 13                           Tom Stienstra 2019-02-11 12:00:00
# 14            Tony Bravo and Laura Compton 2019-02-21 01:30:28
# 15                         George McCalman 2019-02-15 18:35:17
# 16                           Tom Stienstra 2019-02-14 12:00:00
# 17                       Laura Mauk-Caines 2018-02-16 20:52:05
# 18                          Gregory Thomas 2019-02-20 18:20:59
# 19                           Spencer Silva 2019-02-04 22:23:23
# 20                          Deborah Bishop 2017-07-18 17:57:27
# 21                       Catherine Bigelow 2019-02-07 00:40:32
# 22                         Megan Michelson 2019-02-15 20:37:29
# 23                            Kitty Morgan 2017-09-22 18:11:48
# 24                              Pam Peirce 2019-02-01 18:02:33
# 25                           Tom Stienstra 2019-02-07 04:42:00
# 26                             Clara Hogan 2018-03-13 17:45:49
# 27                             David Ferry 2019-02-15 18:28:23
# 28                             Eric Branch 2018-12-23 12:00:00
# 29                           Ron Kroichick 2019-02-11 05:54:55
# ..                                     ...                 ...
# 111                          Rusty Simmons 2018-12-24 12:00:00
# 112                            Ann Killion 2018-12-21 12:00:00
# 113                          Ron Kroichick                 NaT
# 114                          Ron Kroichick 2019-02-14 04:03:14
# 115      Joseph Pisani and Alexandra Olson 2019-02-15 03:24:18
# 116  ELAINE KURTENBACH, AP Business Writer 2019-02-19 04:04:10
# 117                           Jordan Guinn 2019-02-16 17:17:19
# 118                           Carolyn Said 2018-02-16 14:00:00
# 119                       Dominic Fracassa 2019-02-15 00:55:14
# 120                            J.D. Morris 2019-02-11 23:04:43
# 121                           Carolyn Said 2019-02-20 01:53:14
# 122                    Daisuke Wakabayashi 2019-02-13 23:15:41
# 123          Kaori Hitomi and Danica Kirka 2019-02-19 23:39:22
# 124                      Anne D’Innocenzio 2019-02-20 00:15:03
# 125                            J.D. Morris 2019-02-19 12:00:00
# 126                          Melia Russell 2019-02-16 01:00:00
# 127                                   None 2019-02-16 03:41:20
# 128                           Carolyn Said                 NaT
# 129                           Don Thompson 2019-02-14 22:43:14
# 130      ANNABELLE LIANG, Associated Press 2019-02-18 03:31:32
# 131                            J.D. Morris 2019-02-13 00:02:44
# 132                            J.D. Morris 2019-02-14 04:59:31
# 133                                   None 2019-02-16 03:42:17
# 134                       Associated Press 2019-02-19 23:56:00
# 135                        Kathleen Pender 2019-02-16 12:00:00
# 136          Joe McDonald and Paul Wiseman 2019-02-19 23:52:58
# 137            Kelvin Chan and Rob Gillies 2019-02-13 23:20:57
# 138                Sentinel Media Services 2019-02-16 17:16:34
# 139         ALEX VEIGA, AP Business Writer 2019-02-19 22:09:53
# 140  ELAINE KURTENBACH, AP Business Writer 2019-02-19 12:16:02
#
#            date_updated                                               text  \
# 0   2017-09-27 17:44:41  If you’ve never seen a fox in a fig tree, you ...
# 1   2019-02-12 22:52:42  An ancient garment is having a major moment in...
# 2                   NaT  For more stories like this, check out The Chro...
# 3   2019-02-18 18:26:03  Hospitals are not always places of joy. But a ...
# 4   2019-02-08 19:09:12  For more stories like this, check out The Chro...
# 5   2019-02-08 19:45:59  In Paradise, Oroville and the surrounding regi...
# 6   2019-02-16 19:18:08  In 1897, Emperor Meiji sent my grandfather to ...
# 7   2019-02-19 17:44:01  You could leave right now and in a matter of h...
# 8                   NaT  Boasting gorgeous rosettes painted in frosty b...
# 9   2019-02-20 17:41:22  Nearly 1,200 hearts burst with joy the night b...
# 10  2019-02-07 22:30:44  Mira Pickett describes her style as “undone do...
# 11                  NaT  Three new fragrances meant to evoke experience...
# 12  2019-02-19 17:43:41  From Del Valle Reservoir to the Sierra Crest, ...
# 13  2019-02-11 19:55:58  As  raindrops fell over the weekend, the state...
# 14  2019-02-21 01:31:11  When fashion designer Karl Lagerfeld died on T...
# 15  2019-02-18 19:16:16  Artist and creative director George McCalman c...
# 16  2019-02-14 12:00:33  Near Donner Summit, crews at Donner Ski Ranch ...
# 17  2018-02-20 16:53:51  Karla Gallardo and Shilpa Shah, co-founders of...
# 18                  NaT  By age 6, Cody Townsend knew he wanted to be a...
# 19  2019-02-20 19:03:37  For more stories like this, check out The Chro...
# 20  2017-07-18 18:30:10  The rope swing that dangles down 15 feet from ...
# 21  2019-02-07 00:42:01  We’re fairly certain we’d never catch Chronicl...
# 22                  NaT  With back-to-back storms and feet upon feet of...
# 23  2017-09-22 19:01:16  San Franciscans have a love-hate relationship ...
# 24  2019-02-01 18:12:53  The book “Gardenlust: A Botanical Tour of the ...
# 25  2019-02-07 04:42:44  From Mount Hood in Sonoma County, it isn’t dif...
# 26  2018-03-13 18:11:06  Trish Crawley’s entry into her 30s didn’t happ...
# 27  2019-02-15 18:50:11  For more stories like this, check out The Chro...
# 28  2018-12-27 23:14:09  Last year, after he was hired despite having z...
# 29  2019-02-11 05:56:26  PEBBLE BEACH — A brief, ferocious hailstorm sl...
# ..                  ...                                                ...
# 111 2018-12-31 09:08:00  Cal head women’s basketball coach Lindsay Gott...
# 112 2018-12-27 23:11:10  Her journey took some twists and turns, but Ab...
# 113                 NaT  High school football players on 14 mostly Bay ...
# 114 2019-02-14 04:03:55  Tiger Woods will play alongside Rory McIlroy a...
# 115 2019-02-15 03:25:36  NEW YORK — Amazon abruptly dropped plans Thurs...
# 116 2019-02-19 04:05:48  BANGKOK (AP) — Asian shares are mostly higher ...
# 117 2019-02-16 17:18:29  Despite his penchant for building multimillion...
# 118 2018-02-18 00:18:33  If anyone knew the ropes about Airbnb rentals,...
# 119 2019-02-15 00:56:10  More than 250,000 San Francisco homes and busi...
# 120 2019-02-11 23:05:47  Half of the PG&E Corp. board of directors will...
# 121 2019-02-20 01:53:58  Some San Francisco taxi drivers, their busines...
# 122                 NaT  A former senior lawyer at Apple who oversaw th...
# 123                 NaT  LONDON — Japanese carmaker Honda plans to clos...
# 124                 NaT  Walmart defied a gloomy government retail sale...
# 125 2019-02-19 12:00:33  To meet its aggressive goals for fighting clim...
# 126                 NaT  As it faces competition from more focused tran...
# 127                 NaT  On the market for the first time in more than ...
# 128                 NaT  Under the threat of huge penalties, Airbnb, Ho...
# 129                 NaT  SACRAMENTO — Gov. Gavin Newsom set off a flurr...
# 130 2019-02-18 03:34:21  SINGAPORE (AP) — Asian markets were broadly hi...
# 131 2019-02-13 00:03:56  Jobs in California’s once-steadily growing sol...
# 132 2019-02-14 23:57:55  While millions more Pacific Gas and Electric C...
# 133 2019-02-16 03:43:48  Legally a two-unit building, this luxurious ho...
# 134                 NaT  LONDON — Twitter said Tuesday that it is tight...
# 135 2019-02-17 05:47:29  Readers had several questions about my recent ...
# 136                 NaT  WASHINGTON — The United States and China resum...
# 137                 NaT  TORONTO — Canada’s national game — brought to ...
# 138 2019-02-16 17:17:27  A: Real estate today moves at the speed of inf...
# 139 2019-02-19 22:19:55  Stocks shook off an early wobble on Wall Stree...
# 140 2019-02-19 12:18:23  BANGKOK (AP) — Stock mostly fell in Europe and...
#
#                                                  title  \
# 0      Modern Carmel Valley home welcomes land and sky
# 1    Asian Art Museum shows the kimono’s internatio...
# 2    Podcast: Ultrarunner Dean Karnazes on recovery...
# 3    Galas galore: CPMC celebrates new hospital, SF...
# 4    Lake Tahoe houses sit vacant while locals stru...
# 5    Feather Falls: California’s prettiest waterfal...
# 6    How Brenda Wong Aoki rocks the kimono — past, ...
# 7    Where’s the closest place to find snow near Sa...
# 8                    Beauty and brawn: Gotta get agave
# 9    Hearts in San Francisco gala breaks a record f...
# 10   Mira Pickett wants to help you fall in love wi...
# 11   New fragrances bottle the natural world, from ...
# 12                 The good and bad from recent storms
# 13      Weekend rain fills and tops off Bay Area lakes
# 14   Remembering Karl Lagerfeld in San Francisco, a...
# 15   Observed: A banner month for art, dance and ideas
# 16   Snow dump means great skiing in Tahoe this wee...
# 17   Fashion-brand co-founders: Two homes, one aest...
# 18   Podcast: Cody Townsend on what it takes to be ...
# 19                 Top 9 things to do in Amador County
# 20   Remodel creates an airy house of mirth for family
# 21   Nion McEvoy receives inaugural Di Rosa Award a...
# 22      6 things to do in Tahoe when you get snowed in
# 23   AIASF Home Tour: Architects get creative with ...
# 24   ‘Gardenlust’ looks at best 21st century garden...
# 25            Spring hike: Mount Hood in Sonoma County
# 26   Piece by piece, an apartment transforms into a...
# 27   Could you survive hiking alone across Death Va...
# 28   49ers’ GM John Lynch will be the one to watch ...
# 29   Hailstorm slams Pebble Beach during final roun...
# ..                                                 ...
# 111  Cal chancellor Carol Christ looks to unify aca...
# 112  Abby Dalhkemper’s journey to the spine of U.S....
# 113                                    Tomorrow’s game
# 114  Tiger Woods, Phil Mickelson not ready to relin...
# 115  Amazon dumps NYC headquarters and its promised...
# 116  Asian shares gain on hopes for progress on Chi...
# 117    Designer Profile: Lowell Strauss of Amalfi West
# 118  Long, winding road to SF’s get-tough registrat...
# 119  CleanPowerSF tripling households served with m...
# 120  PG&E to replace half of its board in wake of b...
# 121  SF airport rules meant to help some cabbies an...
# 122  Former Apple compliance lawyer charged with in...
# 123       Honda to shut plant in Brexit-shaken Britain
# 124  Walmart beats expectations in holiday season e...
# 125  Can California homes and businesses quit natur...
# 126  Lime dropped the ‘bike’ from its name; now the...
# 127  Three-bedroom in Greenbrae on the market for t...
# 128  SF short-term rentals transformed as Airbnb, o...
# 129      Newsom wants users to profit from online data
# 130  Asian stocks rally on hope of further China-US...
# 131         California solar jobs fall for second year
# 132  PG&E says it’s still trying to limit power shu...
# 133    Five-bedroom north of Lake District open Sunday
# 134  Twitter tightens up EU political ad rules ahea...
# 135  Answers to readers’ tax questions on college s...
# 136  US, China resume trade talks in Washington ahe...
# 137  Huawei makes global marketing push amid diplom...
# 138  What’s a piece of technology you can’t imagine...
# 139  US stocks bounce back from wobbly start to ext...
# 140  World stocks turn lower ahead of more China-US...
#
#                                                    url    category
# 0    https://www.sfchronicle.com/homeandgarden/arti...   lifestyle
# 1    https://www.sfchronicle.com/style/article/Asia...   lifestyle
# 2    https://www.sfchronicle.com/travel/article/Pod...   lifestyle
# 3    https://www.sfchronicle.com/style/article/Gala...   lifestyle
# 4    https://www.sfchronicle.com/travel/article/Lak...   lifestyle
# 5    https://www.sfchronicle.com/travel/article/Fea...   lifestyle
# 6    https://www.sfchronicle.com/style/article/How-...   lifestyle
# 7    https://www.sfchronicle.com/travel/article/Whe...   lifestyle
# 8    https://www.sfchronicle.com/homeandgarden/arti...   lifestyle
# 9    https://www.sfchronicle.com/style/article/Hear...   lifestyle
# 10   https://www.sfchronicle.com/style/article/Mira...   lifestyle
# 11   https://www.sfchronicle.com/style/article/New-...   lifestyle
# 12   https://www.sfchronicle.com/travel/article/The...   lifestyle
# 13   https://www.sfchronicle.com/outdoors/stienstra...   lifestyle
# 14   https://www.sfchronicle.com/style/article/Reme...   lifestyle
# 15   https://www.sfchronicle.com/style/article/Obse...   lifestyle
# 16   https://www.sfchronicle.com/travel/article/Sno...   lifestyle
# 17   https://www.sfchronicle.com/homeandgarden/arti...   lifestyle
# 18   https://www.sfchronicle.com/travel/article/Pod...   lifestyle
# 19   https://www.sfchronicle.com/travel/article/Nin...   lifestyle
# 20   https://www.sfchronicle.com/food/article/Remod...   lifestyle
# 21   https://www.sfchronicle.com/living/article/Nio...   lifestyle
# 22   https://www.sfchronicle.com/travel/article/6-t...   lifestyle
# 23   https://www.sfchronicle.com/homeandgarden/arti...   lifestyle
# 24   https://www.sfchronicle.com/homeandgarden/arti...   lifestyle
# 25   https://www.sfchronicle.com/travel/article/Spr...   lifestyle
# 26   https://www.sfchronicle.com/homeandgarden/arti...   lifestyle
# 27   https://www.sfchronicle.com/travel/article/Cou...   lifestyle
# 28   https://www.sfchronicle.com/49ers/article/49er...      sports
# 29   https://www.sfchronicle.com/sports/golf/articl...      sports
# ..                                                 ...         ...
# 111  https://www.sfchronicle.com/collegesports/arti...      sports
# 112  https://www.sfchronicle.com/sports/annkillion/...      sports
# 113  https://www.sfchronicle.com/sports/article/The...      sports
# 114  https://www.sfchronicle.com/sports/kroichick/a...      sports
# 115  https://www.sfchronicle.com/business/article/A...  Biz + tech
# 116  https://www.sfchronicle.com/news/world/article...  Biz + tech
# 117  https://www.sfchronicle.com/realestate/article...  Biz + tech
# 118  https://www.sfchronicle.com/business/article/L...  Biz + tech
# 119  https://www.sfchronicle.com/bayarea/article/Cl...  Biz + tech
# 120  https://www.sfchronicle.com/business/article/P...  Biz + tech
# 121  https://www.sfchronicle.com/business/article/S...  Biz + tech
# 122  https://www.sfchronicle.com/business/article/F...  Biz + tech
# 123  https://www.sfchronicle.com/business/article/H...  Biz + tech
# 124  https://www.sfchronicle.com/business/article/W...  Biz + tech
# 125  https://www.sfchronicle.com/business/article/C...  Biz + tech
# 126  https://www.sfchronicle.com/business/article/L...  Biz + tech
# 127  https://www.sfchronicle.com/realestate/article...  Biz + tech
# 128  https://www.sfchronicle.com/business/article/S...  Biz + tech
# 129  https://www.sfchronicle.com/business/article/N...  Biz + tech
# 130  https://www.sfchronicle.com/news/world/article...  Biz + tech
# 131  https://www.sfchronicle.com/business/article/C...  Biz + tech
# 132  https://www.sfchronicle.com/business/article/P...  Biz + tech
# 133  https://www.sfchronicle.com/realestate/article...  Biz + tech
# 134  https://www.sfchronicle.com/business/article/T...  Biz + tech
# 135  https://www.sfchronicle.com/business/networth/...  Biz + tech
# 136  https://www.sfchronicle.com/business/article/U...  Biz + tech
# 137  https://www.sfchronicle.com/business/article/H...  Biz + tech
# 138  https://www.sfchronicle.com/realestate/article...  Biz + tech
# 139  https://www.sfchronicle.com/news/article/US-st...  Biz + tech
# 140  https://www.sfchronicle.com/news/world/article...  Biz + tech
#
# [141 rows x 7 columns]

# %% [markdown]
# __Exercise 1.4.__  What topics has the Chronicle covered recently? How does the category affect the topics? Support your analysis with visualizations.
#
# Hints:
#
# *   The [nltk book](http://www.nltk.org/book/) may be helpful here.
#
# *   This question will be easier to do after we've finished NLP in class.

# %%
# All the stop words from each category defined below that i found from the initial graphs for each category

biz_sw = ['said','new',"san","you","also","pg","would","year","could","one","percent","000","city","get","companies"]
sports_sw = ["two","time","last","first","three","10","12"]
lifestyle_sw = ["www","like","says","com",]
all_sw = biz_sw + sports_sw + lifestyle_sw

def tokenize(text):
    
    '''Function will take in a text, and returns a list of all the words, not including stop 
    words in that text'''
    
    # Get all words in the text
    all_words = re.findall('\w+',text) 
    
    # Get all unique words, as some words may be the same but one might be a different case
    uni_words = [] 
    for word in all_words:
        uni_words.append(word.lower())
        

    # Get rid of all the stop words
    sw = nltk.corpus.stopwords.words("english")
    sw = sw + all_sw
    
    # Get words that aren't stop words 
    ns_words = []
    for i in uni_words:
        if i not in sw and len(i) > 1:
            ns_words.append(i)
   
    return ns_words

# %% [markdown]
# ###### Getting the frequency of the most common words per category and graphing it

# %%
all_lists = [tokenize(i) for i in full_df["text"]]
all_lists = list(chain(*all_lists)) # used to unlist the list of lists
freqdist_all = nltk.FreqDist(all_lists)

# %%
biz_lists = [tokenize(i) for i in biz_df["text"]]
biz_lists = list(chain(*biz_lists)) 
freqdist_biz = nltk.FreqDist(biz_lists)

# %%
sports_lists = [tokenize(i) for i in sports_df["text"]]
sports_lists = list(chain(*sports_lists))
freqdist_sports = nltk.FreqDist(sports_lists)

# %%
lifestyle_lists = [tokenize(i) for i in lifestyle_df["text"]]
lifestyle_lists = list(chain(*lifestyle_lists))
freqdist_lifestyle = nltk.FreqDist(lifestyle_lists)

# %%
plt.title("Frequency of the most common words for all three sub-categories")
freqdist_all.plot(20)

plt.title("Frequency of the most common words for buisness")
freqdist_biz.plot(20)

plt.title("Frequency of the most common words for sports")
freqdist_sports.plot(20)

plt.title("Frequency of the most common words for lifestyle")
freqdist_lifestyle.plot(20)

# %% [markdown]
# ##### Topics covered recently by the Chronicle:
# Looking at the first figure, frequency of the most common words for all three sub-categories , Amongst those three categroires the most occured phrases were game,season,football,points. This therefore leads me to believe the Chronicle has been covering a lot of sports lately, which makes sense to me as since i am a sports fanatic i know there's alot going on in the sports world right now. Also, there's alot of information on san francisco so the chronicle has been covering that alor pretty recently which makes sense as the newspaper is based in san francisco.

# %% [markdown]
# ##### The category effect on the topics:
#
# I believe, the category has a big effect on the topic of the words.  As seen when i dissect ecah sub category, there is not much overlap among the topics, as mentioned above words like game,season,football and points are only under the sports section, but a small amount of words like francisco overlap among the lifestyle and buisness categories. Furthermore, this leads me to the conclusion that, for the most part each sub-category will have its own unique topic that it will cover which will not be presented within other sub-categories.
